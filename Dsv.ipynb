# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
uploaded = files.upload()
filename = list(uploaded.keys())[0]

df = pd.read_csv(filename)
print("\n✅ Dataset loaded successfully!")
print(df.head())
print(df.info())
median_crime = df['TOTAL IPC CRIMES'].median()
df['Crime_Level'] = (df['TOTAL IPC CRIMES'] > median_crime).astype(int)


X = df[['STATE/UT', 'YEAR', 'MURDER']]
y = df['Crime_Level']

X = pd.get_dummies(X, columns=['STATE/UT'], drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

model = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f"Features Used: STATE/UT, YEAR, MURDER (STATE/UT One-Hot Encoded)")
print(f"Accuracy: {accuracy*100:.2f}%")
# Out:
#      <input type="file" id="files-37c91851-f2f6-4cc2-8ea5-d53405d51d77" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-37c91851-f2f6-4cc2-8ea5-d53405d51d77">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 1. Configure your identity (use the email linked to your GitHub account)
# !git config --global user.name "https://github.com/lalith-sky"\

# 2. Clone your existing repository (This creates a folder in Colab's file system)
# Replace 'YourUsername' and 'YourRepoName' with your actual details.
# !git clone https://github.com/lalith-sky/mlproject.git
# Out:
# Cloning into 'mlproject'...
# ...

# %%
# %cd mlproject
# Out:
# /content/mlproject

# %%
# !git add .

# %%
# !git commit -m "Add final model with 85.20% accuracy"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@d98481c8fc35.(none)')

# %%
# !pip install PyGithub

from github import Github

# --- ENTER YOUR TOKEN AND REPO NAME ---
TOKEN = !pip install PyGithub

from github import Github

# --- ENTER YOUR TOKEN AND REPO NAME ---
[REMOVED]repo_name = "my-colab-ml-pro"   # change name as you like
description = "ML project uploaded automatically from Google Colab"

# GitHub login
g = Github(TOKEN)

# Get user (your account: lalith-sky)
user = g.get_user()

# Create repo
repo = user.create_repo(repo_name, description=description, private=False)

print("✅ Repository created successfully!")
print("🔗 Repo URL:", repo.clone_url)
  # Paste token inside quotes
repo_name = "my-colab-ml-project"   # change name as you like
description = "ML project uploaded automatically from Google Colab"

# GitHub login
g = Github(TOKEN)

# Get user (your account: lalith-sky)
user = g.get_user()

# Create repo
repo = user.create_repo(repo_name, description=description, private=False)

print("✅ Repository created successfully!")
print("🔗 Repo URL:", repo.clone_url)
# Out:
# ...
# /tmp/ipython-input-1400735361.py:16: DeprecationWarning: Argument login_or_token is deprecated, please use auth=github.Auth.Token(...) instead
#   g = Github(TOKEN)
# ✅ Repository created successfully!
# 🔗 Repo URL: https://github.com/lalith-sky/my-colab-ml-pro.git
# /tmp/ipython-input-1400735361.py:31: DeprecationWarning: Argument login_or_token is deprecated, please use auth=github.Auth.Token(...) instead
#   g = Github(TOKEN)
# ---------------------------------------------------------------------------
# GithubException                           Traceback (most recent call last)
# /tmp/ipython-input-1400735361.py in <cell line: 0>()
#      35
#      36 # Create repo
# ---> 37 repo = user.create_repo(repo_name, description=description, private=False)
#      38
#      39 print("✅ Repository created successfully!")
#
# ...

# %%
from github import Github

TOKEN = "PASTE_YOUR_TOKEN_HERE"

# CHANGE REPO NAME HERE
repo_name = "my-colab-ml-project"
description = "ML project uploaded automatically from Google Colab"

g = Github(TOKEN)
user = g.get_user()

repo = user.create_repo(repo_name, description=description, private=False)

print("✅ Repository created successfully!")
print("🔗 Repo URL:", repo.clone_url)
# Out:
# /tmp/ipython-input-993311727.py:9: DeprecationWarning: Argument login_or_token is deprecated, please use auth=github.Auth.Token(...) instead
#   g = Github(TOKEN)
# ---------------------------------------------------------------------------
# BadCredentialsException                   Traceback (most recent call last)
# /tmp/ipython-input-993311727.py in <cell line: 0>()
#      10 user = g.get_user()
#      11
# ---> 12 repo = user.create_repo(repo_name, description=description, private=False)
#      13
#      14 print("✅ Repository created successfully!")
#
# /usr/local/lib/python3.12/dist-packages/github/AuthenticatedUser.py in create_repo(self, name, description, homepage, private, has_issues, has_wiki, has_downloads, has_projects, has_discussions, auto_init, license_template, gitignore_template, allow_squash_merge, allow_merge_commit, allow_rebase_merge, delete_branch_on_merge)
#     632         )
#     633
# ...

# %%
# !git config --global user.email "Lalith@142107@gmail.com"
# !git config --global user.name "lalith-sky"

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/.git/

# %%
# !git add .

# %%
# !git commit -m "Initial commit"
# Out:
# [main (root-commit) 67cf366] Initial commit
#  21 files changed, 51025 insertions(+)
#  create mode 100644 .config/.last_opt_in_prompt.yaml
#  create mode 100644 .config/.last_survey_prompt.yaml
#  create mode 100644 .config/.last_update_check.json
#  create mode 100644 .config/active_config
#  create mode 100644 .config/config_sentinel
#  create mode 100644 .config/configurations/config_default
#  create mode 100644 .config/default_configs.db
#  create mode 100644 .config/gce
#  create mode 100644 .config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db
#  create mode 100644 .config/logs/2025.11.12/14.29.51.386235.log
#  create mode 100644 .config/logs/2025.11.12/14.30.15.789373.log
#  create mode 100644 .config/logs/2025.11.12/14.30.24.701531.log
#  create mode 100644 .config/logs/2025.11.12/14.30.26.280314.log
#  create mode 100644 .config/logs/2025.11.12/14.30.35.156140.log
#  create mode 100644 .config/logs/2025.11.12/14.30.35.902193.log
# ...

# %%
git remote add origin https://github.com/lalith-sky/my-colab-ml-pro.git
# Out:
#   File "/tmp/ipython-input-1188072470.py", line 1
#     git remote add origin https://github.com/lalith-sky/my-colab-ml-pro.git
#         ^
# SyntaxError: invalid syntax

# %%
# Change directory to your project folder where the cloned repository is located
# %cd /content/mlproject

# Configure user identity locally for this repository
# !git config user.email "Lalith@142107@gmail.com"
# !git config user.name "lalith-sky"

# Add all relevant project files (e.g., notebook, data) to the staging area
# !git add .

# Commit the changes
# !git commit -m "Initial commit of project files"

# Ensure the branch is named 'main'
# !git branch -M main

# Remove existing remote 'origin' if it exists. The '|| true' prevents the cell from failing if origin doesn't exist.
# !git remote remove origin || true

# Add the new remote with the Personal Access Token (PAT) for authentication
[REMOVED]REPO_URL = f"https://{TOKEN}@github.com/lalith-sky/my-colab-ml-pro.git"
# !git remote add origin {REPO_URL}

# Push the committed changes to the 'main' branch on GitHub
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/.git/
# [main f7cac1d] first commit
#  1 file changed, 1 insertion(+)
# [REMOVED]

# %%
[REMOVED]REPO_URL = f"https://{TOKEN}:x-oauth-basic@github.com/lalith-sky/my-colab-ml-project.git"

# %%
# !git remote remove origin || true
# !git remote add origin {REPO_URL}

# %%
# !git push -u origin main
# Out:
# remote: Invalid username or token. Password authentication is not supported for Git operations.
# fatal: Authentication failed for 'https://github.com/lalith-sky/my-colab-ml-project.git/'

# %%
# !git remote remove origin || true

# %%
[REMOVED]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# [REMOVED]
# [REMOVED]

# %%
[REMOVED]REPO_URL = f"https://{NEW_TOKEN}:x-oauth-basic@github.com/lalith-sky/my-colab-ml-project.git"

# !git remote add origin {REPO_URL}

# %%
# !git push -u origin main
# Out:
# Enumerating objects: 34, done.
# Counting objects: 100% (34/34), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (25/25), done.
# Writing objects: 100% (34/34), 8.42 MiB | 2.19 MiB/s, done.
# Total 34 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), done.
# To https://github.com/lalith-sky/my-colab-ml-project.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
from google.colab import files
files.download('Dsv.ipynb')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1991717997.py in <cell line: 0>()
#       1 from google.colab import files
# ----> 2 files.download('Dsv.ipynb')
#       3
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: Dsv.ipynb

# %%
# !ls
# Out:
# README.md  sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/Dsv.ipynb" .

# %%
# !ls
# Out:
# drive  Dsv.ipynb  sample_data

# %%
# !git add Dsv.ipynb
# !git commit -m "Added main notebook"
# !git push
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !pwd
# !ls -a
# Out:
# /content
# .  ..  .config	drive  Dsv.ipynb  sample_data

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# !git add Dsv.ipynb

# %%
# !git commit -m "Added main notebook"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@14af78d55457.(none)')

# %%
[REMOVED]REPO_URL = f"https://{TOKEN}:x-oauth-basic@github.com/lalith-sky/my-colab-ml-project.git"

# !git remote add origin {REPO_URL}

# %%
# !git branch -M main
# !git push -u origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/lalith-sky/my-colab-ml-project.git'

# %%
# !pwd
# !ls -a
# Out:
# /content
# .  ..  .config	drive  Dsv.ipynb  .git	sample_data

# %%
# !git add Dsv.ipynb

# %%
# !git commit -m "first commit"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@14af78d55457.(none)')

# %%
# !git config --global user.email "Lalith@142107@gmail.com"
# !git config --global user.name "lalith-sky"

# %%
# !git config --global --list
# Out:
# user.email=Lalith@142107@gmail.com
# user.name=lalith-sky

# %%
# !git add Dsv.ipynb
# !git commit -m "added notebook"
# Out:
# [main (root-commit) dd10360] added notebook
#  1 file changed, 1 insertion(+)
#  create mode 100644 Dsv.ipynb

# %%
# !git add Dsv.ipynb
# !git commit -m "added notebook"
# Out:
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.config/
# 	drive/
# 	sample_data/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !ls -l
# Out:
# total 56
# drwx------ 5 root root  4096 Nov 14 11:57 drive
# -rw------- 1 root root 47433 Nov 14 11:57 Dsv.ipynb
# drwxr-xr-x 1 root root  4096 Nov 12 14:30 sample_data

# %%
# !git add Dsv.ipynb

# %%
# !git commit -m "Added main notebook"
# Out:
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.config/
# 	drive/
# 	sample_data/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git config --global user.email "Lalith@142107@gmail.com"
# !git config --global user.name "lalith-sky"

# %%
# !git branch -M main

# %%
[REMOVED]REPO_URL = f"https://{TOKEN}:x-oauth-basic@github.com/lalith-sky/my-colab-ml-project.git"

# !git remote remove origin || true
# !git remote add origin {REPO_URL}

# %%
# !git push -u origin main
# Out:
# To https://github.com/lalith-sky/my-colab-ml-project.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/lalith-sky/my-colab-ml-project.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git fetch origin main
# Out:
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 34 (delta 5), reused 34 (delta 5), pack-reused 0 (from 0)
# Unpacking objects: 100% (34/34), 8.42 MiB | 7.17 MiB/s, done.
# From https://github.com/lalith-sky/my-colab-ml-project
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %%
# !git merge origin/main --allow-unrelated-histories
# Out:
# error: The following untracked working tree files would be overwritten by merge:
# 	.config/.last_opt_in_prompt.yaml
# 	.config/.last_survey_prompt.yaml
# 	.config/.last_update_check.json
# 	.config/active_config
# 	.config/config_sentinel
# 	.config/configurations/config_default
# 	.config/default_configs.db
# 	.config/gce
# 	.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db
# 	.config/logs/2025.11.12/14.29.51.386235.log
# 	.config/logs/2025.11.12/14.30.15.789373.log
# 	.config/logs/2025.11.12/14.30.24.701531.log
# 	.config/logs/2025.11.12/14.30.26.280314.log
# 	.config/logs/2025.11.12/14.30.35.156140.log
# 	.config/logs/2025.11.12/14.30.35.902193.log
# 	sample_data/README.md
# 	sample_data/anscombe.json
# 	sample_data/california_housing_test.csv
# 	sample_data/california_housing_train.csv
# 	sample_data/mnist_test.csv
# 	sample_data/mnist_train_small.csv
# Please move or remove them before you merge.
# Aborting

# %%
# !git rm -r --cached .config sample_data drive
# Out:
# fatal: pathspec '.config' did not match any files

# %%
# !git clean -fd
# Out:
# Removing .config/
# ...
# Removing drive/MyDrive/DocScanner 7 Dec 2021 6.01 pm (1).pdf
# Removing drive/MyDrive/DocScanner 7 Dec 2021 6.01 pm.pdf
# Removing drive/MyDrive/Achyuthaditya resume.docx
# Removing drive/MyDrive/recording2022-09-09 21-39-50-2.mp3
# Removing drive/MyDrive/Takeout
# Removing drive/MyDrive/UnderTaking_Letter Y24 lalith.gdoc
# Removing drive/MyDrive/Untitled spreadsheet.gsheet
# Removing drive/MyDrive/HASHING.py.gdoc
# Removing drive/MyDrive/Colab Notebooks
# Removing drive/MyDrive/twitter_training.csv
# Removing drive/MyDrive/natural_disasters_2024.csv
# Removing drive/MyDrive/home
# Removing drive/MyDrive/Legal Notice Shiva Krishna.gdoc
# Removing drive/MyDrive/Legal Notice Shiva Krishna-1 (1).gdoc
# Removing drive/MyDrive/Legal Notice Shiva Krishna-1.gdoc
# Removing drive/MyDrive/BAIL PETITION - 437 - CRIME 133 of 2025 final-second time.gdoc
# Removing drive/MyDrive/crime_dataset_india.csv
# Removing drive/MyDrive/JAVA week-1.pdf
# ...

# %%
# !git merge origin/main --allow-unrelated-histories
# Out:
# hint: Waiting for your editor to close the file... 7[>4;2m="/content/.git/MERGE_MSG" 6L, 269B▽  Pzz\[0%m           [>cMerge remote-tracking branch 'origin/main'
# # Please enter a commit message to explain why this merge is necessary,# especially if it merges an updated upstream into a topic branch.#
# # Lines starting with '#' will be ignored, and an empty message aborts
# # the commit.
# ...

# %%
:q!
# Out:
#   File "/tmp/ipython-input-483785981.py", line 1
#     :q!
#     ^
# SyntaxError: invalid syntax

# %%
# !git fetch origin
# !git reset --hard origin/main
# Out:
# HEAD is now at f7cac1d first commit

# %%
# !ls -l
# Out:
# total 12
# drwx------ 5 root root 4096 Nov 14 11:57 drive
# -rw-r--r-- 1 root root   36 Nov 14 12:10 README.md
# drwxr-xr-x 2 root root 4096 Nov 14 12:10 sample_data

# %%
# !git add Dsv.ipynb
# !git commit -m "Added notebook"
# Out:
# fatal: pathspec 'Dsv.ipynb' did not match any files
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	drive/
#
# nothing added to commit but untracked files present (use "git add" to track)
